# %%
from datetime import date

import pandas as pd
import numpy as np

from matplotlib.pylab import plt

import seaborn as sns

from scipy import stats

# %matplotlib inline

sns.set_style("white")
sns.set_context('talk')

# %matplotlib inline

# %% [markdown]
# # Setup

# %% [markdown]
# ## Raw Dataset
# Switched to using a daily dataset from https://www.ecdc.europa.eu/en/novel-coronavirus-china
# The main reason for this is that this dataset goes back to 31/12/2019 whereas the JH dataset starts about a month later when China already had 500+ cases and 17 deaths.

# %%
ecdc_dataset_raw = 'https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide{}.xlsx'

ecdc_dataset_processed = '../data/processed/ecdc_dataset.csv'

# %%
todays_date = "-{}-{:02}-{:02}".format(date.today().year, date.today().month, date.today().day)

df = pd.read_excel(ecdc_dataset_raw.format(todays_date))

df.columns = ['date', 'day', 'month', 'year', 'cases', 'deaths', 'country', 'code', 'pop']

# Add a number of days since records began column.
df['day'] = (df['date'] - df['date'].min()).map(lambda d: d.days)

# Sort by day, oldest first
df = df.sort_values(by='day', ascending=True).set_index('day')

df.shape
# Out:
# (6738, 8)

# %%
df.country.unique()
# Out:
# array(['Indonesia', 'United_Arab_Emirates', 'Austria', 'Switzerland',
#        'Nepal', 'Brazil', 'India', 'Lebanon', 'Malaysia',
#        'Cases_on_an_international_conveyance_Japan', 'Azerbaijan',
#        'Estonia', 'Iceland', 'Russia', 'Netherlands', 'Thailand',
#        'Finland', 'Afghanistan', 'United_States_of_America', 'Bahrain',
#        'New_Zealand', 'Philippines', 'United_Kingdom', 'Singapore',
#        'China', 'Kuwait', 'Egypt', 'Japan', 'Denmark', 'Pakistan',
#        'Armenia', 'Italy', 'South_Korea', 'Mexico', 'Taiwan', 'Algeria',
#        'Romania', 'Iran', 'Monaco', 'Cambodia', 'Israel', 'Ireland',
#        'Australia', 'Ecuador', 'Canada', 'Czech_Republic', 'Oman', 'Iraq',
#        'Croatia', 'Dominican_Republic', 'Qatar', 'Norway', 'Germany',
#        'France', 'San_Marino', 'Sri_Lanka', 'Spain', 'North_Macedonia',
#        'Georgia', 'Sweden', 'Nigeria', 'Greece', 'Belarus', 'Luxembourg',
#        'Lithuania', 'Vietnam', 'Belgium', 'Portugal', 'Jordan', 'Latvia',
#        'Andorra', 'Saudi_Arabia', 'Senegal', 'Tunisia', 'Morocco',
#        'Poland', 'Ukraine', 'Chile', 'Argentina', 'Hungary',
#        'Liechtenstein', 'Slovenia', 'South_Africa', 'Bhutan',
#        'Bosnia_and_Herzegovina', 'Palestine', 'Holy_See', 'Togo',
#        'Cameroon', 'Colombia', 'Serbia', 'Slovakia', 'Costa_Rica', 'Peru',
#        'Paraguay', 'Malta', 'Maldives', 'Bulgaria', 'Moldova', 'Albania',
#        'Bangladesh', 'Brunei_Darussalam', 'Panama', 'Mongolia', 'Cyprus',
#        'Democratic_Republic_of_the_Congo', 'Burkina_Faso', 'Cote_dIvoire',
#        'Jamaica', 'Cuba', 'Turkey', 'Bolivia', 'Honduras',
#        'Trinidad_and_Tobago', 'Saint_Vincent_and_the_Grenadines', 'Ghana',
#        'Guyana', 'Gabon', 'Sudan', 'Ethiopia', 'Guinea', 'Kenya',
#        'Kazakhstan', 'Equatorial_Guinea', 'Eswatini', 'Namibia',
#        'Seychelles', 'Venezuela', 'Antigua_and_Barbuda', 'Mauritania',
#        'Rwanda', 'Suriname', 'Saint_Lucia', 'Uruguay', 'Guatemala',
#        'Central_African_Republic', 'Uzbekistan', 'Kosovo', 'Congo',
#        'Bahamas', 'Liberia', 'Somalia', 'Myanmar', 'Benin',
#        'United_Republic_of_Tanzania', 'Gambia', 'Barbados', 'Montenegro',
#        'CANADA', 'Zambia', 'Nicaragua', 'El_Salvador', 'Kyrgyzstan',
#        'Guam', 'Djibouti', 'French_Polynesia', 'Haiti', 'Mauritius',
#        'Faroe_Islands', 'Greenland', 'Cayman_Islands', 'Chad',
#        'Gibraltar', 'Netherlands_Antilles', 'Guernsey', 'Bermuda',
#        'Jersey', 'Fiji', 'Zimbabwe', 'Papua_New_Guinea', 'Montserrat',
#        'Isle_of_Man', 'Niger', 'Madagascar', 'New_Caledonia',
#        'Cape_Verde', 'Timor_Leste', 'Angola', 'Uganda', 'Eritrea',
#        'Grenada', 'Syria', 'Dominica', 'Mozambique', 'Belize',
#        'United_States_Virgin_Islands', 'Laos', 'Libya',
#        'Turks_and_Caicos_islands'], dtype=object)

# %%
df.head()
# Out:
#           date  month  year  cases  deaths               country code  \
# day
# 0   2019-12-31     12  2019      0       0             Indonesia   ID
# 0   2019-12-31     12  2019      0       0  United_Arab_Emirates   AE
# 0   2019-12-31     12  2019      0       0               Austria   AT
# 0   2019-12-31     12  2019      0       0           Switzerland   CH
# 0   2019-12-31     12  2019      0       0                 Nepal   NP
#
#              pop
# day
# 0    267663435.0
# 0      9630959.0
# 0      8847037.0
# 0      8516543.0
# 0     28087871.0

# %% [markdown]
# # Processing

# %% [markdown]
# ## Add Cumulative Totals

# %%
df['cum_cases'] = df.groupby('country')['cases'].transform('cumsum')
df['cum_deaths'] = df.groupby('country')['deaths'].transform('cumsum')

# %%
cum_cases_pct_change = df.groupby('country').apply(lambda g: g['cum_cases'].pct_change())
cum_deaths_pct_change = df.groupby('country').apply(lambda g: g['cum_deaths'].pct_change())

df = df.reset_index()\
        .set_index(['country', 'day'])\
        .join(cum_cases_pct_change, rsuffix='_pct_change')\
        .join(cum_deaths_pct_change, rsuffix='_pct_change')

df.sample()
# Out:
#                     date  month  year  cases  deaths code         pop  \
# country   day
# Australia 26  2020-01-26      1  2020      3       0   AU  24992369.0
#
#                cum_cases  cum_deaths  cum_cases_pct_change  \
# country   day
# Australia 26           4           0                   3.0
#
#                cum_deaths_pct_change
# country   day
# Australia 26                     NaN

# %%
df['cum_cases_pct_change'] = df['cum_cases_pct_change'].replace(np.inf, np.nan)
df['cum_deaths_pct_change'] = df['cum_deaths_pct_change'].replace(np.inf, np.nan)

df.shape
# Out:
# (6738, 11)

# %% [markdown]
# ## Calculate Log10 Values

# %%
df = df.reset_index().set_index('day')
df.sample()
# Out:
#                                         country       date  month  year  \
# day
# 30   Cases_on_an_international_conveyance_Japan 2020-01-30      1  2020
#
#      cases  deaths      code  pop  cum_cases  cum_deaths  \
# day
# 30       0       0  JPG11668  NaN          0           0
#
#      cum_cases_pct_change  cum_deaths_pct_change
# day
# 30                    NaN                    NaN

# %%
cum_cases_log10 = df.groupby('country').apply(lambda g: g['cum_cases'].map(lambda n: np.log10(n) if n>0 else np.nan))
cum_deaths_log10 = df.groupby('country').apply(lambda g: g['cum_deaths'].map(lambda n: np.log10(n) if n>0 else np.nan))

df = df.reset_index()\
    .set_index(['country', 'day'])\
    .join(cum_cases_log10, rsuffix='_log10')\
    .join(cum_deaths_log10, rsuffix='_log10')

df.head()
# Out:
#                                date  month  year  cases  deaths code  \
# country              day
# Indonesia            0   2019-12-31     12  2019      0       0   ID
# United_Arab_Emirates 0   2019-12-31     12  2019      0       0   AE
# Austria              0   2019-12-31     12  2019      0       0   AT
# Switzerland          0   2019-12-31     12  2019      0       0   CH
# Nepal                0   2019-12-31     12  2019      0       0   NP
#
#                                   pop  cum_cases  cum_deaths  \
# country              day
# Indonesia            0    267663435.0          0           0
# United_Arab_Emirates 0      9630959.0          0           0
# Austria              0      8847037.0          0           0
# Switzerland          0      8516543.0          0           0
# Nepal                0     28087871.0          0           0
#
#                           cum_cases_pct_change  cum_deaths_pct_change  \
# country              day
# Indonesia            0                     NaN                    NaN
# United_Arab_Emirates 0                     NaN                    NaN
# Austria              0                     NaN                    NaN
# Switzerland          0                     NaN                    NaN
# Nepal                0                     NaN                    NaN
#
#                           cum_cases_log10  cum_deaths_log10
# country              day
# Indonesia            0                NaN               NaN
# United_Arab_Emirates 0                NaN               NaN
# Austria              0                NaN               NaN
# Switzerland          0                NaN               NaN
# Nepal                0                NaN               NaN

# %% [markdown]
# ## Calculate Doubling Time

# %%
df = df.reset_index().set_index('day')
df.sample()
# Out:
#      country       date  month  year  cases  deaths code        pop  \
# day
# 12   Austria 2020-01-12      1  2020      0       0   AT  8847037.0
#
#      cum_cases  cum_deaths  cum_cases_pct_change  cum_deaths_pct_change  \
# day
# 12           0           0                   NaN                    NaN
#
#      cum_cases_log10  cum_deaths_log10
# day
# 12               NaN               NaN

# %%
def doubling_time(s, d=5): return d*(np.log(2)/np.log(s/s.shift(d)))

cum_cases_dt = df.groupby('country').apply(lambda g: doubling_time(g['cum_cases']))

df = df.reset_index()\
    .set_index(['country', 'day'])\
    .join(cum_cases_dt, rsuffix='_dt')

df.sample()
# Out:
#                                date  month  year  cases  deaths code  \
# country              day
# United_Arab_Emirates 11  2020-01-11      1  2020      0       0   AE
#
#                                 pop  cum_cases  cum_deaths  \
# country              day
# United_Arab_Emirates 11   9630959.0          0           0
#
#                           cum_cases_pct_change  cum_deaths_pct_change  \
# country              day
# United_Arab_Emirates 11                    NaN                    NaN
#
#                           cum_cases_log10  cum_deaths_log10  cum_cases_dt
# country              day
# United_Arab_Emirates 11               NaN               NaN           NaN

# %% [markdown]
# # Calculate Day Zero Days
# To align the cases/deaths across different countries we choose a staring day based on when countries reach 100/10 cases/deaths.

# %%
df = df.reset_index().set_index('day')
df.sample()
# Out:
#     country       date  month  year  cases  deaths code  pop  cum_cases  \
# day
# 66   Taiwan 2020-03-06      3  2020      2       0   TW  NaN         44
#
#      cum_deaths  cum_cases_pct_change  cum_deaths_pct_change  cum_cases_log10  \
# day
# 66            1              0.047619                    0.0         1.643453
#
#      cum_deaths_log10  cum_cases_dt
# day
# 66                0.0     28.730778

# %%
def day_with_n_at_least_k(g, k): 
        
    # The zero_day offset
    d = g[g>=k].index.values[0] if g.max()>=k else np.nan
        
    return pd.Series(g.index.values-d, name='day', index=g.index.values)


min_cases, min_deaths = 100, 10


day_zero_for_cases = df.groupby('country').apply(
    lambda g: day_with_n_at_least_k(g['cum_cases'], min_cases)).reset_index()
day_zero_for_cases.columns = ['country', 'day', 'day_zero_cases']

day_zero_for_deaths = df.groupby('country').apply(
    lambda g: day_with_n_at_least_k(g['cum_deaths'], min_deaths)).reset_index()
day_zero_for_deaths.columns = ['country', 'day', 'day_zero_deaths']

df = df.reset_index()\
    .set_index(['country', 'day'])\
    .join(day_zero_for_cases.set_index(['country', 'day']))\
    .join(day_zero_for_deaths.set_index(['country', 'day']))\

    
df.sample()
# Out:
#                   date  month  year  cases  deaths code         pop  \
# country day
# Egypt   20  2020-01-20      1  2020      0       0   EG  98423595.0
#
#              cum_cases  cum_deaths  cum_cases_pct_change  \
# country day
# Egypt   20           0           0                   NaN
#
#              cum_deaths_pct_change  cum_cases_log10  cum_deaths_log10  \
# country day
# Egypt   20                     NaN              NaN               NaN
#
#              cum_cases_dt  day_zero_cases  day_zero_deaths
# country day
# Egypt   20            NaN           -56.0            -63.0

# %% [markdown]
# # Save Processed Datasets

# %%
df.reset_index().to_csv(ecdc_dataset_processed, index=False)

df.shape
# Out:
# (6738, 16)

# %%
df
# Out:
#                                date  month  year  cases  deaths code  \
# country              day
# Indonesia            0   2019-12-31     12  2019      0       0   ID
# United_Arab_Emirates 0   2019-12-31     12  2019      0       0   AE
# Austria              0   2019-12-31     12  2019      0       0   AT
# Switzerland          0   2019-12-31     12  2019      0       0   CH
# Nepal                0   2019-12-31     12  2019      0       0   NP
# ...                             ...    ...   ...    ...     ...  ...
# New_Caledonia        85  2020-03-25      3  2020      2       0   NC
# Haiti                85  2020-03-25      3  2020      2       0   HT
# Cambodia             85  2020-03-25      3  2020      4       0   KH
# Rwanda               85  2020-03-25      3  2020      4       0   RW
# Afghanistan          85  2020-03-25      3  2020      2       0   AF
#
#                                   pop  cum_cases  cum_deaths  \
# country              day
# Indonesia            0    267663435.0          0           0
# United_Arab_Emirates 0      9630959.0          0           0
# Austria              0      8847037.0          0           0
# Switzerland          0      8516543.0          0           0
# Nepal                0     28087871.0          0           0
# ...                               ...        ...         ...
# New_Caledonia        85      284060.0          9           0
# Haiti                85    11123176.0          7           0
# Cambodia             85    16249798.0         91           0
# Rwanda               85    12301939.0         40           0
# Afghanistan          85    37172386.0         42           1
#
#                           cum_cases_pct_change  cum_deaths_pct_change  \
# country              day
# Indonesia            0                     NaN                    NaN
# United_Arab_Emirates 0                     NaN                    NaN
# Austria              0                     NaN                    NaN
# Switzerland          0                     NaN                    NaN
# Nepal                0                     NaN                    NaN
# ...                                        ...                    ...
# New_Caledonia        85               0.285714                    NaN
# Haiti                85               0.400000                    NaN
# Cambodia             85               0.045977                    NaN
# Rwanda               85               0.111111                    NaN
# Afghanistan          85               0.050000                    0.0
#
#                           cum_cases_log10  cum_deaths_log10  cum_cases_dt  \
# country              day
# Indonesia            0                NaN               NaN           NaN
# United_Arab_Emirates 0                NaN               NaN           NaN
# Austria              0                NaN               NaN           NaN
# Switzerland          0                NaN               NaN           NaN
# Nepal                0                NaN               NaN           NaN
# ...                                   ...               ...           ...
# New_Caledonia        85          0.954243               NaN           NaN
# Haiti                85          0.845098               NaN      2.766474
# Cambodia             85          1.959041               NaN      2.600331
# Rwanda               85          1.602060               NaN      2.684569
# Afghanistan          85          1.623249               0.0      5.359713
#
#                           day_zero_cases  day_zero_deaths
# country              day
# Indonesia            0             -76.0            -80.0
# United_Arab_Emirates 0             -78.0              NaN
# Austria              0             -69.0            -83.0
# Switzerland          0             -67.0            -75.0
# Nepal                0               NaN              NaN
# ...                                  ...              ...
# New_Caledonia        85              NaN              NaN
# Haiti                85              NaN              NaN
# Cambodia             85              NaN              NaN
# Rwanda               85              NaN              NaN
# Afghanistan          85              NaN              NaN
#
# [6738 rows x 16 columns]

# %%
df.reset_index().set_index('country').loc['Spain'].reset_index().set_index('day_zero_deaths').loc[-5:]
# Out:
#                 country  day       date  month  year  cases  deaths code  \
# day_zero_deaths
# -5.0              Spain   65 2020-03-05      3  2020     49       1   ES
# -4.0              Spain   66 2020-03-06      3  2020     61       2   ES
# -3.0              Spain   67 2020-03-07      3  2020    113       2   ES
# -2.0              Spain   68 2020-03-08      3  2020     56       0   ES
# -1.0              Spain   69 2020-03-09      3  2020    159       0   ES
#  0.0              Spain   70 2020-03-10      3  2020    615      23   ES
#  1.0              Spain   71 2020-03-11      3  2020    435       7   ES
#  2.0              Spain   72 2020-03-12      3  2020    501      12   ES
#  3.0              Spain   73 2020-03-13      3  2020    864      37   ES
#  4.0              Spain   74 2020-03-14      3  2020   1227      37   ES
#  5.0              Spain   75 2020-03-15      3  2020   1522      15   ES
#  6.0              Spain   76 2020-03-16      3  2020   2000     152   ES
#  7.0              Spain   77 2020-03-17      3  2020   1438      21   ES
#  8.0              Spain   78 2020-03-18      3  2020   1987     182   ES
#  9.0              Spain   79 2020-03-19      3  2020   2538     107   ES
#  10.0             Spain   80 2020-03-20      3  2020   3431     169   ES
#  11.0             Spain   81 2020-03-21      3  2020   2833     235   ES
#  12.0             Spain   82 2020-03-22      3  2020   4946     324   ES
#  13.0             Spain   83 2020-03-23      3  2020   3646     394   ES
#  14.0             Spain   84 2020-03-24      3  2020   4517     462   ES
#  15.0             Spain   85 2020-03-25      3  2020   6584     514   ES
#
#                         pop  cum_cases  cum_deaths  cum_cases_pct_change  \
# day_zero_deaths
# -5.0             46723749.0        200           1              0.324503
# -4.0             46723749.0        261           3              0.305000
# -3.0             46723749.0        374           5              0.432950
# -2.0             46723749.0        430           5              0.149733
# -1.0             46723749.0        589           5              0.369767
#  0.0             46723749.0       1204          28              1.044143
#  1.0             46723749.0       1639          35              0.361296
#  2.0             46723749.0       2140          47              0.305674
#  3.0             46723749.0       3004          84              0.403738
#  4.0             46723749.0       4231         121              0.408455
#  5.0             46723749.0       5753         136              0.359726
#  6.0             46723749.0       7753         288              0.347645
#  7.0             46723749.0       9191         309              0.185477
#  8.0             46723749.0      11178         491              0.216190
#  9.0             46723749.0      13716         598              0.227053
#  10.0            46723749.0      17147         767              0.250146
#  11.0            46723749.0      19980        1002              0.165218
#  12.0            46723749.0      24926        1326              0.247548
#  13.0            46723749.0      28572        1720              0.146273
#  14.0            46723749.0      33089        2182              0.158092
#  15.0            46723749.0      39673        2696              0.198979
#
#                  cum_deaths_pct_change  cum_cases_log10  cum_deaths_log10  \
# day_zero_deaths
# -5.0                               NaN         2.301030          0.000000
# -4.0                          2.000000         2.416641          0.477121
# -3.0                          0.666667         2.572872          0.698970
# -2.0                          0.000000         2.633468          0.698970
# -1.0                          0.000000         2.770115          0.698970
#  0.0                          4.600000         3.080626          1.447158
#  1.0                          0.250000         3.214579          1.544068
#  2.0                          0.342857         3.330414          1.672098
#  3.0                          0.787234         3.477700          1.924279
#  4.0                          0.440476         3.626443          2.082785
#  5.0                          0.123967         3.759894          2.133539
#  6.0                          1.117647         3.889470          2.459392
#  7.0                          0.072917         3.963363          2.489958
#  8.0                          0.588997         4.048364          2.691081
#  9.0                          0.217923         4.137227          2.776701
#  10.0                         0.282609         4.234188          2.884795
#  11.0                         0.306389         4.300595          3.000868
#  12.0                         0.323353         4.396653          3.122544
#  13.0                         0.297134         4.455941          3.235528
#  14.0                         0.268605         4.519684          3.338855
#  15.0                         0.235564         4.598495          3.430720
#
#                  cum_cases_dt  day_zero_cases
# day_zero_deaths
# -5.0                 1.955881             2.0
# -4.0                 2.520781             3.0
# -3.0                 2.302179             4.0
# -2.0                 2.610553             5.0
# -1.0                 2.546189             6.0
#  0.0                 1.930678             7.0
#  1.0                 1.886298             8.0
#  2.0                 1.986886             9.0
#  3.0                 1.782864            10.0
#  4.0                 1.757680            11.0
#  5.0                 2.215842            12.0
#  6.0                 2.230213            13.0
#  7.0                 2.377996            14.0
#  8.0                 2.637541            15.0
#  9.0                 2.946742            16.0
#  10.0                3.173455            17.0
#  11.0                3.661046            18.0
#  12.0                3.473772            19.0
#  13.0                3.692926            20.0
#  14.0                3.935484            21.0
#  15.0                4.131544            22.0
